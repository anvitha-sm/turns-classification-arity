# %% [markdown]
# <a href="https://colab.research.google.com/github/anvitha-sm/turns-classification-arity/blob/main/turns-classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import osmnx as ox
import geopandas as gpd
from sklearn.preprocessing import StandardScaler

# %%
pd.set_option('display.max_columns', None)
ios_data = pd.read_csv("ios_turns.csv")
android_data = pd.read_csv("android_turns.csv")

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### iOS data

# %%
ios_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61094 entries, 0 to 61093
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   init_time                          61094 non-null  float64
#  1   eventAction                        61094 non-null  float64
#  2   payloadCreation                    61094 non-null  float64
#  3   eventStart                         61094 non-null  float64
#  4   eventEnd                           61094 non-null  float64
#  5   eventType                          61094 non-null  float64
#  6   eventSampleSpeed                   61094 non-null  float64
#  7   eventDurationSeconds               61094 non-null  float64
#  8   eventMilesDriven                   61094 non-null  float64
#  9   eventStartLatitude                 61094 non-null  float64
#  10  eventStartLongitude                61094 non-null  float64
#  11  eventEndLatitude                   61094 non-null  float64
#  12  eventEndLongitude                  61094 non-null  float64
#  13  eventSensorDetectionMthd           61094 non-null  float64
#  14  eventGPSSignalStrength             61094 non-null  float64
#  15  eventStartSpeed                    61094 non-null  float64
#  16  eventEndSpeed                      61094 non-null  float64
#  17  eventSpeedChange                   61094 non-null  int64
#  18  memsMedianLateralAccel             61094 non-null  float64
#  19  memsP75LateralAccel                61094 non-null  float64
#  20  memsP95LateralAccel                61094 non-null  float64
#  21  memsMedianHorizontalNorm           61094 non-null  float64
#  22  memsP75HorizontalNorm              61094 non-null  float64
#  23  memsP95HorizontalNorm              61094 non-null  float64
#  24  gpsMedianLateralAccel              61094 non-null  float64
#  25  gpsP75LateralAccel                 61094 non-null  float64
#  26  gpsP95LateralAccel                 61094 non-null  float64
#  27  bearing_angular_change_per_second  61094 non-null  float64
#  28  gyro_angular_change_per_second     61094 non-null  float64
#  29  bearingAngleChange                 60859 non-null  float64
#  30  gyroAngleChange                    61094 non-null  float64
#  31  mems_radius                        61094 non-null  float64
#  32  gps_radius                         61091 non-null  float64
#  33  validity_mean                      61094 non-null  float64
# dtypes: float64(33), int64(1)
# memory usage: 15.8 MB

# %%
ios_data.describe()
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py:52: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#           init_time  eventAction  payloadCreation    eventStart      eventEnd  \
# count  6.109400e+04      61094.0          61094.0  6.109400e+04  6.109400e+04
# mean   1.720234e+12          1.0              1.0  1.094169e+06  1.099123e+06
# std    8.282511e+09          0.0              0.0  2.183122e+06  2.183208e+06
# min    1.702584e+12          1.0              1.0  2.952144e+03  4.847230e+03
# 25%    1.712613e+12          1.0              1.0  2.249281e+05  2.298995e+05
# 50%    1.721009e+12          1.0              1.0  5.614414e+05  5.665474e+05
# 75%    1.726888e+12          1.0              1.0  1.253427e+06  1.258467e+06
# max    1.736258e+12          1.0              1.0  6.362140e+07  6.363137e+07
#
#           eventType  eventSampleSpeed  eventDurationSeconds  eventMilesDriven  \
# count  61094.000000      61094.000000          61094.000000      61094.000000
# mean       4.512440         15.616635              4.954434          0.022619
# std        0.499849         15.057503              3.088469          0.025124
# min        4.000000          5.001024              0.914496          0.000000
# 25%        4.000000          9.713930              2.958125          0.010235
# 50%        5.000000         13.658226              4.655649          0.016879
# 75%        5.000000         18.821297              6.152793          0.027195
# max        5.000000       1307.922100             24.980251          1.908790
#
#        eventStartLatitude  eventStartLongitude  eventEndLatitude  \
# count        61094.000000         61094.000000      61094.000000
# mean            38.531441           -87.817148         38.531441
# std              5.932518            22.629689          5.932514
# min              6.968758          -159.761980          6.968711
# 25%             35.235588           -89.412760         35.235524
# 50%             41.803113           -87.875563         41.803111
# 75%             42.158978           -82.405621         42.158894
# max             56.830097            25.482054         56.829945
#
#        eventEndLongitude  eventSensorDetectionMthd  eventGPSSignalStrength  \
# count       61094.000000              61094.000000            61094.000000
# mean          -87.817154                  1.131011                6.818543
# std            22.629691                  0.926085                8.378248
# min          -159.761500                  0.000000                2.000000
# 25%           -89.412432                  0.000000                4.740406
# 50%           -87.875155                  2.000000                4.756594
# 75%           -82.405650                  2.000000                7.059539
# max            25.482030                  2.000000              477.784180
#
#        eventStartSpeed  eventEndSpeed  eventSpeedChange  \
# count     61094.000000   61094.000000           61094.0
# mean         15.287629      16.974019              -1.0
# std          19.745252      14.044510               0.0
# min          -2.236940      -2.236940              -1.0
# 25%           8.131329      11.164708              -1.0
# 50%          13.314892      15.510978              -1.0
# 75%          19.834566      20.721055              -1.0
# max        2618.081300    1221.429100              -1.0
#
#        memsMedianLateralAccel  memsP75LateralAccel  memsP95LateralAccel  \
# count            61094.000000         61094.000000         61094.000000
# mean                 1.178195             1.801076             2.473796
# std                  0.995345             1.207450             1.776872
# min                  0.000000             0.005836             0.009053
# 25%                  0.427068             0.997171             1.493121
# 50%                  0.993460             1.590590             2.210316
# 75%                  1.699174             2.334050             3.063695
# max                 15.893914            25.367445            54.141556
#
#        memsMedianHorizontalNorm  memsP75HorizontalNorm  memsP95HorizontalNorm  \
# count              61094.000000           61094.000000           61094.000000
# mean                   2.005137               2.529723               3.290195
# std                    1.135880               1.426561               2.285000
# min                    0.007562               0.009754               0.014992
# 25%                    1.311046               1.733309               2.279898
# 50%                    1.842418               2.331026               2.977058
# 75%                    2.451394               3.009022               3.764590
# max                   29.881191              35.152584              63.657814
#
#        gpsMedianLateralAccel  gpsP75LateralAccel  gpsP95LateralAccel  \
# count           61094.000000        61094.000000        61094.000000
# mean                1.474784            2.664718            3.561963
# std                 1.845171            7.134243            7.284046
# min                -0.089241            0.000000            0.000000
# 25%                 0.345133            1.489937            2.119720
# 50%                 1.212294            2.383681            3.218249
# 75%                 2.133511            3.515874            4.555012
# max               275.073360         1625.099200         1625.099200
#
#        bearing_angular_change_per_second  gyro_angular_change_per_second  \
# count                       61094.000000                    61094.000000
# mean                           16.155392                       12.060006
# std                            11.350997                        6.093657
# min                             0.000000                        0.000121
# 25%                             9.257651                        7.919867
# 50%                            13.744654                       12.079066
# 75%                            18.918240                       16.067764
# max                           186.620740                      158.511840
#
#        bearingAngleChange  gyroAngleChange    mems_radius    gps_radius  \
# count        60859.000000     61094.000000   61094.000000  6.109100e+04
# mean            72.868898        59.401857     154.769521           NaN
# std             39.745732        40.479495    3347.202429           NaN
# min              0.000000         0.000137       0.286599          -inf
# 25%             45.924542        26.880174      13.241270  1.676608e+01
# 50%             76.711080        59.295506      24.250653  5.296442e+01
# 75%             90.302572        86.108830      49.206554  3.753227e+02
# max            726.318100       455.013920  348236.470000           inf
#
#        validity_mean
# count        61094.0
# mean             1.0
# std              0.0
# min              1.0
# 25%              1.0
# 50%              1.0
# 75%              1.0
# max              1.0

# %%
ios_data.head()
# Out:
#       init_time  eventAction  payloadCreation  eventStart   eventEnd  \
# 0  1.713042e+12          1.0              1.0   479553.47  484875.20
# 1  1.713042e+12          1.0              1.0   459179.94  464064.80
# 2  1.713042e+12          1.0              1.0   448020.16  456677.90
# 3  1.713042e+12          1.0              1.0   427011.25  434835.00
# 4  1.713042e+12          1.0              1.0   395398.60  402547.22
#
#    eventType  eventSampleSpeed  eventDurationSeconds  eventMilesDriven  \
# 0        4.0          8.553064              5.321719          0.014196
# 1        4.0          9.360758              4.884875          0.012575
# 2        5.0         10.681455              8.657750          0.021795
# 3        5.0         10.399240              7.823751          0.016130
# 4        4.0          8.345368              7.148625          0.017785
#
#    eventStartLatitude  eventStartLongitude  eventEndLatitude  \
# 0           41.966473            -87.76243         41.966328
# 1           41.966442            -87.76127         41.966496
# 2           41.966310            -87.76071         41.966347
# 3           41.966670            -87.75977         41.966540
# 4           41.968548            -87.76115         41.968323
#
#    eventEndLongitude  eventSensorDetectionMthd  eventGPSSignalStrength  \
# 0         -87.762570                       2.0                5.384603
# 1         -87.761470                       2.0                5.895552
# 2         -87.761116                       2.0                5.291993
# 3         -87.759950                       2.0                4.910240
# 4         -87.761220                       2.0                4.965302
#
#    eventStartSpeed  eventEndSpeed  eventSpeedChange  memsMedianLateralAccel  \
# 0         8.536157       9.551594                -1                0.037169
# 1         9.034532      10.596797                -1                0.206046
# 2        11.082506      10.390737                -1                0.798037
# 3        15.013917       8.630282                -1                0.014152
# 4         6.963474       9.905923                -1                0.017696
#
#    memsP75LateralAccel  memsP95LateralAccel  memsMedianHorizontalNorm  \
# 0             0.752549             1.175032                  0.608627
# 1             0.810490             1.413861                  0.546008
# 2             1.205643             1.884131                  1.024676
# 3             1.179473             1.692096                  0.984073
# 4             0.601755             1.030918                  0.675187
#
#    memsP75HorizontalNorm  memsP95HorizontalNorm  gpsMedianLateralAccel  \
# 0               0.977264               1.619349               0.917817
# 1               0.846859               1.440432               0.298834
# 2               1.354444               2.017049               0.404701
# 3               1.397610               1.996034               0.000000
# 4               1.029938               1.593058               0.908760
#
#    gpsP75LateralAccel  gpsP95LateralAccel  bearing_angular_change_per_second  \
# 0            1.414616            1.659606                          14.507535
# 1            0.323955            2.006506                           6.688964
# 2            0.639127            0.752962                           4.451903
# 3            0.135585            6.447024                          12.498045
# 4            0.968915            1.698010                          10.938344
#
#    gyro_angular_change_per_second  bearingAngleChange  gyroAngleChange  \
# 0                       17.503620           72.763930        93.844490
# 1                        7.615370           28.435398        37.502575
# 2                        6.722845           42.455890        58.471710
# 3                       12.015339           97.785550        94.482200
# 4                       11.460243           35.474804        82.380120
#
#    mems_radius  gps_radius  validity_mean
# 0     5.143511   20.190279            1.0
# 1    21.282076   56.273140            1.0
# 2    61.868423   60.049355            1.0
# 3    11.925367         inf            1.0
# 4     8.483684   16.327477            1.0

# %% [markdown]
# ### Android data

# %%
android_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1287 entries, 0 to 1286
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   init_time                          1287 non-null   float64
#  1   eventAction                        1287 non-null   int64
#  2   payloadCreation                    1287 non-null   int64
#  3   eventStart                         1287 non-null   float64
#  4   eventEnd                           1287 non-null   float64
#  5   eventType                          1287 non-null   int64
#  6   eventSampleSpeed                   1287 non-null   float64
#  7   eventDurationSeconds               1287 non-null   float64
#  8   eventMilesDriven                   1287 non-null   float64
#  9   eventStartLatitude                 1287 non-null   float64
#  10  eventStartLongitude                1287 non-null   float64
#  11  eventEndLatitude                   1287 non-null   float64
#  12  eventEndLongitude                  1287 non-null   float64
#  13  eventSensorDetectionMthd           1287 non-null   int64
#  14  eventGPSSignalStrength             1287 non-null   float64
#  15  eventStartSpeed                    1287 non-null   float64
#  16  eventEndSpeed                      1287 non-null   float64
#  17  eventSpeedChange                   1287 non-null   int64
#  18  memsMedianLateralAccel             1287 non-null   float64
#  19  memsP75LateralAccel                1287 non-null   float64
#  20  memsP95LateralAccel                1287 non-null   float64
#  21  memsMedianHorizontalNorm           1287 non-null   float64
#  22  memsP75HorizontalNorm              1287 non-null   float64
#  23  memsP95HorizontalNorm              1287 non-null   float64
#  24  gpsMedianLateralAccel              1287 non-null   float64
#  25  gpsP75LateralAccel                 1287 non-null   float64
#  26  gpsP95LateralAccel                 1287 non-null   float64
#  27  bearing_angular_change_per_second  1287 non-null   float64
#  28  gyro_angular_change_per_second     1287 non-null   float64
#  29  bearingAngleChange                 1287 non-null   float64
#  30  gyroAngleChange                    1287 non-null   float64
#  31  mems_radius                        1287 non-null   float64
#  32  gps_radius                         1287 non-null   float64
#  33  validity_mean                      1287 non-null   int64
# dtypes: float64(28), int64(6)
# memory usage: 342.0 KB

# %%
android_data.describe()

# %%
android_data.head()

# %% [markdown]
# ## Checking for Null Values

# %% [markdown]
# ### iOS data

# %%
ios_data.isnull().sum()
# Out:
# init_time                              0
# eventAction                            0
# payloadCreation                        0
# eventStart                             0
# eventEnd                               0
# eventType                              0
# eventSampleSpeed                       0
# eventDurationSeconds                   0
# eventMilesDriven                       0
# eventStartLatitude                     0
# eventStartLongitude                    0
# eventEndLatitude                       0
# eventEndLongitude                      0
# eventSensorDetectionMthd               0
# eventGPSSignalStrength                 0
# eventStartSpeed                        0
# eventEndSpeed                          0
# eventSpeedChange                       0
# memsMedianLateralAccel                 0
# memsP75LateralAccel                    0
# memsP95LateralAccel                    0
# memsMedianHorizontalNorm               0
# memsP75HorizontalNorm                  0
# memsP95HorizontalNorm                  0
# gpsMedianLateralAccel                  0
# gpsP75LateralAccel                     0
# gpsP95LateralAccel                     0
# bearing_angular_change_per_second      0
# gyro_angular_change_per_second         0
# bearingAngleChange                   235
# gyroAngleChange                        0
# mems_radius                            0
# gps_radius                             3
# validity_mean                          0
# dtype: int64

# %% [markdown]
# *The* only features that have null values for the iOS data are bearingAngleChange and gps_radius. Both of these features are used only when the alignmentState is 0, so below, we find the observations where alignmentState is 0 and one or both of the aforementioned features are null.

# %%
ios_data[(ios_data['eventSensorDetectionMthd'] == 0) & (ios_data['bearingAngleChange'].isnull() | ios_data['gps_radius'].isnull())]
# Out:
#           init_time  eventAction  payloadCreation  eventStart   eventEnd  \
# 39031  1.712530e+12          1.0              1.0   85907.766  89863.516
#
#        eventType  eventSampleSpeed  eventDurationSeconds  eventMilesDriven  \
# 39031        5.0         10.670135               3.95575           0.26103
#
#        eventStartLatitude  eventStartLongitude  eventEndLatitude  \
# 39031           31.537205           -84.305275         31.533419
#
#        eventEndLongitude  eventSensorDetectionMthd  eventGPSSignalStrength  \
# 39031          -84.30538                       0.0                199.9895
#
#        eventStartSpeed  eventEndSpeed  eventSpeedChange  \
# 39031              0.0       53.35067                -1
#
#        memsMedianLateralAccel  memsP75LateralAccel  memsP95LateralAccel  \
# 39031                0.630801             0.670978             0.735697
#
#        memsMedianHorizontalNorm  memsP75HorizontalNorm  memsP95HorizontalNorm  \
# 39031                  1.183661               1.265265                1.34548
#
#        gpsMedianLateralAccel  gpsP75LateralAccel  gpsP95LateralAccel  \
# 39031                    0.0                 0.0            74.60431
#
#        bearing_angular_change_per_second  gyro_angular_change_per_second  \
# 39031                          45.309402                        0.240965
#
#        bearingAngleChange  gyroAngleChange  mems_radius  gps_radius  \
# 39031            358.4575         0.962825    145716.94         NaN
#
#        validity_mean
# 39031            1.0

# %% [markdown]
# There is only one observation that has a null value that is actually relevant given the alignment state. We choose to simply remove this observation, so our dataset is still large with only real, measured data. Losing this one observation will not meaningfully impact the performance of our model.

# %%
print(f"iOS count: {(np.isinf(ios_data['gps_radius']) & (ios_data['eventSensorDetectionMthd'] == 0)).sum()}")

# %%
rows_to_delete = (
    (ios_data["eventSensorDetectionMthd"] == 0) &
    (
        ios_data["bearingAngleChange"].isna() |
        ios_data["gps_radius"].isna() |
        np.isinf(ios_data["gps_radius"])
    )
)

ios_data = ios_data.loc[~rows_to_delete].copy()
print("Rows dropped:", rows_to_delete.sum())
print("Remaining rows:", len(ios_data))
# Out:
# Rows dropped: 247
# Remaining rows: 60847

# %%
ios_data.describe()

# %% [markdown]
# ### Android data

# %%
android_data.isnull().sum()

# %%
print(f"Android count: {(np.isinf(android_data['gps_radius']) & (android_data['eventSensorDetectionMthd'] == 0)).sum()}")

# %% [markdown]
# There are no observations in the Android dataset with null values, so we simply retain the entire dataset

# %% [markdown]
# ## Visualizations

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

gdf_points = gpd.GeoDataFrame(
    ios_data,
    geometry=gpd.points_from_xy(ios_data["eventStartLongitude"], ios_data["eventStartLatitude"]),
    crs="EPSG:4326"
)

world = gpd.read_file(
    "https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_countries.zip"
)[["NAME", "geometry"]]
world = world.to_crs(gdf_points.crs)

gdf_points = gpd.sjoin(
    gdf_points, world, how="left", predicate="within",
    lsuffix="left", rsuffix="country"
).rename(columns={"NAME": "country"})

states_url = "https://www2.census.gov/geo/tiger/GENZ2021/shp/cb_2021_us_state_20m.zip"
states = gpd.read_file(states_url)[["NAME", "geometry"]].to_crs(gdf_points.crs)

usa_points = gdf_points[gdf_points["country"] == "United States of America"].copy()
if not usa_points.empty:
    usa_points = usa_points.reset_index(drop=True)
    states = states.reset_index(drop=True)
    usa_points = gpd.sjoin(
        usa_points, states, how="left", predicate="within",
        lsuffix="left", rsuffix="state"
    ).rename(columns={"NAME": "state"})

    # Merge back by coordinates instead of index
    gdf_points = gdf_points.merge(
        usa_points[["eventStartLongitude", "eventStartLatitude", "state"]],
        on=["eventStartLongitude", "eventStartLatitude"],
        how="left"
    )

fig, ax = plt.subplots(figsize=(15, 8))
world.boundary.plot(ax=ax, linewidth=0.5, color="black")
gdf_points.plot(ax=ax, markersize=3, color="red", alpha=0.5)
plt.title("All iOS points")
plt.show()

print(gdf_points["country"].value_counts())
print(
    gdf_points[gdf_points["country"] == "United States of America"]["state"].value_counts()
)

# %%
gdf_points = gpd.GeoDataFrame(
    android_data,
    geometry=gpd.points_from_xy(android_data["eventStartLongitude"], android_data["eventStartLatitude"]),
    crs="EPSG:4326"
)

world = gpd.read_file(
    "https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_countries.zip"
)[["NAME", "geometry"]]
world = world.to_crs(gdf_points.crs)

gdf_points = gpd.sjoin(
    gdf_points, world, how="left", predicate="within",
    lsuffix="left", rsuffix="country"
).rename(columns={"NAME": "country"})

states_url = "https://www2.census.gov/geo/tiger/GENZ2021/shp/cb_2021_us_state_20m.zip"
states = gpd.read_file(states_url)[["NAME", "geometry"]].to_crs(gdf_points.crs)

usa_points = gdf_points[gdf_points["country"] == "United States of America"].copy()
if not usa_points.empty:
    usa_points = usa_points.reset_index(drop=True)
    states = states.reset_index(drop=True)
    usa_points = gpd.sjoin(
        usa_points, states, how="left", predicate="within",
        lsuffix="left", rsuffix="state"
    ).rename(columns={"NAME": "state"})

    # Merge back by coordinates instead of index
    gdf_points = gdf_points.merge(
        usa_points[["eventStartLongitude", "eventStartLatitude", "state"]],
        on=["eventStartLongitude", "eventStartLatitude"],
        how="left"
    )

fig, ax = plt.subplots(figsize=(15, 8))
world.boundary.plot(ax=ax, linewidth=0.5, color="black")
gdf_points.plot(ax=ax, markersize=3, color="red", alpha=0.5)
plt.title("All Android points")
plt.show()

print(gdf_points["country"].value_counts())
print(
    gdf_points[gdf_points["country"] == "United States of America"]["state"].value_counts()
)

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns
# import numpy as np

# print("--- Histograms for numerical variables (iOS) ---")
# ios_numeric_cols = ios_data.select_dtypes(include=np.number).columns
# for col in ios_numeric_cols:
#     plt.figure(figsize=(10, 5))
#     sns.histplot(ios_data[col], kde=True, bins=30)
#     plt.title(f'Distribution of {col} in iOS Data')
#     plt.xlabel(col)
#     plt.ylabel('Frequency')
#     plt.show()

# print("\n--- Histograms for numerical variables (Android) ---")
# android_numeric_cols = android_data.select_dtypes(include=np.number).columns
# for col in android_numeric_cols:
#     plt.figure(figsize=(10, 5))
#     sns.histplot(android_data[col], kde=True, bins=30, color='orange')
#     plt.title(f'Distribution of {col} in Android Data')
#     plt.xlabel(col)
#     plt.ylabel('Frequency')
#     plt.show()


# print("\n--- Boxplots vs. Event Type (iOS) ---")
# for col in ios_numeric_cols:
#     plt.figure(figsize=(8, 6))
#     sns.boxplot(x='eventType', y=col, data=ios_data)
#     plt.title(f'{col} vs. Event Type in iOS Data')
#     plt.show()

# print("\n--- Boxplots vs. Event Type (Android) ---")
# for col in android_numeric_cols:
#     plt.figure(figsize=(8, 6))
#     sns.boxplot(x='eventType', y=col, data=android_data, palette='Oranges')
#     plt.title(f'{col} vs. Event Type in Android Data')
#     plt.show()


# print("\n--- Correlation Matrix (iOS) ---")
# plt.figure(figsize=(12, 10))
# ios_corr = ios_data[ios_numeric_cols].corr()
# sns.heatmap(ios_corr, cmap='coolwarm')
# plt.title('Correlation Matrix for iOS Data')
# plt.show()

# print("\n--- Correlation Matrix (Android) ---")
# plt.figure(figsize=(12, 10))
# android_corr = android_data[android_numeric_cols].corr()
# sns.heatmap(android_corr, cmap='YlOrBr')
# plt.title('Correlation Matrix for Android Data')
# plt.show()


# print("\n--- Feature Distribution Comparison (iOS vs. Android) ---")
# for col in ios_numeric_cols:
#     plt.figure(figsize=(10, 5))
#     sns.kdeplot(ios_data[col], label='iOS', fill=True, alpha=0.5)
#     sns.kdeplot(android_data[col], label='Android', fill=True, alpha=0.5)
#     plt.title(f'Distribution of {col}: iOS vs. Android')
#     plt.legend()
#     plt.show()

# %%
# for col in numeric_cols:
#     plt.figure(figsize=(8,4))
#     sns.boxplot(x="eventType", y=col, hue="platform", data=ios_data)
#     plt.title(f"{col} vs Event Type (Left/Right Turn) by Platform")
#     plt.show()

# %%
# for col in numeric_cols:
#     plt.figure(figsize=(8,4))
#     sns.boxplot(x="eventType", y=col, hue="platform", data=android_data)
#     plt.title(f"{col} vs Event Type (Left/Right Turn) by Platform")
#     plt.show()

# %%
# plt.figure(figsize=(10,6))
# sns.heatmap(ios_data[numeric_cols].corr(), annot=True, cmap="coolwarm", center=0)
# plt.title("Correlation Matrix of Numeric Variables")
# plt.show()

# %%
# plt.figure(figsize=(10,6))
# sns.heatmap(android_data[numeric_cols].corr(), annot=True, cmap="coolwarm", center=0)
# plt.title("Correlation Matrix of Numeric Variables")
# plt.show()

# %%
# cat_cols = ios_data.select_dtypes(include=["object", "category"]).columns
# for col in cat_cols:
#     if col not in ["platform", "eventType"]:  # exclude target columns
#         plt.figure(figsize=(8,4))
#         sns.countplot(x=col, hue="platform", data=ios_data)
#         plt.title(f"Distribution of {col} by Platform (iOS vs Android)")
#         plt.show()

# %%
# for col in cat_cols:
#     if col not in ["platform", "eventType"]:  # exclude target columns
#         plt.figure(figsize=(8,4))
#         sns.countplot(x=col, hue="platform", data=android_data)
#         plt.title(f"Distribution of {col} by Platform (iOS vs Android)")
#         plt.show()

# %% [markdown]
# ## Plotting with Folium

# %%
import folium
from IPython.display import display

for i, row in ios_data.head(20).iterrows():
    start_coords = (row['eventStartLatitude'], row['eventStartLongitude'])
    end_coords = (row['eventEndLatitude'], row['eventEndLongitude'])

    center_lat = (row['eventStartLatitude'] + row['eventEndLatitude']) / 2
    center_lon = (row['eventStartLongitude'] + row['eventEndLongitude']) / 2
    m = folium.Map(location=[center_lat, center_lon], zoom_start=50)

    folium.Marker(start_coords, popup="Start", icon=folium.Icon(color='green')).add_to(m)
    folium.Marker(end_coords, popup="End", icon=folium.Icon(color='red')).add_to(m)

    folium.PolyLine([start_coords, end_coords], color='blue', weight=2.5, opacity=1).add_to(m)

    display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfd66adceea69aa0004e921bf69e1483 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfd66adceea69aa0004e921bf69e1483&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfd66adceea69aa0004e921bf69e1483 = L.map(
#                 &quot;map_cfd66adceea69aa0004e921bf69e1483&quot;,
#                 {
#                     center: [41.9664005, -87.76249999999999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 50,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6121699409916b224927941e2a26cd32 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6121699409916b224927941e2a26cd32.addTo(map_cfd66adceea69aa0004e921bf69e1483);
#
#
#             var marker_3120fdbc3d19e42aa6d2c64a98e5437c = L.marker(
#                 [41.966473, -87.76243],
#                 {
# }
#             ).addTo(map_cfd66adceea69aa0004e921bf69e1483);
#
#
#             var icon_5af18b6ef342e1c4a0da04094688491b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_aeff566164bbc32f5e317a9b77b91c32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8eab7816f63f0be19902fd098da5528 = $(`&lt;div id=&quot;html_c8eab7816f63f0be19902fd098da5528&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_aeff566164bbc32f5e317a9b77b91c32.setContent(html_c8eab7816f63f0be19902fd098da5528);
#
#
#
#         marker_3120fdbc3d19e42aa6d2c64a98e5437c.bindPopup(popup_aeff566164bbc32f5e317a9b77b91c32)
#         ;
#
#
#
#
#                 marker_3120fdbc3d19e42aa6d2c64a98e5437c.setIcon(icon_5af18b6ef342e1c4a0da04094688491b);
#
#
#             var marker_2110fa83a94925c887a588dfc8c5cdec = L.marker(
#                 [41.966328, -87.76257],
#                 {
# }
#             ).addTo(map_cfd66adceea69aa0004e921bf69e1483);
#
#
#             var icon_573a1d4a64b09e041f29e80bd6637f06 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_87f8048f814a9f1719adeebd68eed116 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e605b31b305feab9cf58d4d547e4c25 = $(`&lt;div id=&quot;html_4e605b31b305feab9cf58d4d547e4c25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;End&lt;/div&gt;`)[0];
#                 popup_87f8048f814a9f1719adeebd68eed116.setContent(html_4e605b31b305feab9cf58d4d547e4c25);
#
#
#
#         marker_2110fa83a94925c887a588dfc8c5cdec.bindPopup(popup_87f8048f814a9f1719adeebd68eed116)
#         ;
#
#
#
#
#                 marker_2110fa83a94925c887a588dfc8c5cdec.setIcon(icon_573a1d4a64b09e041f29e80bd6637f06);
#
#
#             var poly_line_415a9340710ae7e3cd977b88ea8b4e2c = L.polyline(
#                 [[41.966473, -87.76243], [41.966328, -87.76257]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_cfd66adceea69aa0004e921bf69e1483);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7638503ce0461460885430e5c4acdb8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7638503ce0461460885430e5c4acdb8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7638503ce0461460885430e5c4acdb8 = L.map(
#                 &quot;map_f7638503ce0461460885430e5c4acdb8&quot;,
#                 {
#                     center: [41.966469000000004, -87.76137],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 50,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7892bb7abef1adcd780c43d64b40db6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c7892bb7abef1adcd780c43d64b40db6.addTo(map_f7638503ce0461460885430e5c4acdb8);
#
#
#             var marker_82463b5e4791f622760a3083d3c60f24 = L.marker(
#                 [41.966442, -87.76127],
#                 {
# }
#             ).addTo(map_f7638503ce0461460885430e5c4acdb8);
#
#
#             var icon_782c8755e3543325c4d1e095baf7e04e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_378463aeaf739ecbf7b1f1f1c0a3d72d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6789a4e41cbc074a423b12b502cae7bb = $(`&lt;div id=&quot;html_6789a4e41cbc074a423b12b502cae7bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_378463aeaf739ecbf7b1f1f1c0a3d72d.setContent(html_6789a4e41cbc074a423b12b502cae7bb);
#
#
#
#         marker_82463b5e4791f622760a3083d3c60f24.bindPopup(popup_378463aeaf739ecbf7b1f1f1c0a3d72d)
#         ;
#
#
#
#
#                 marker_82463b5e4791f622760a3083d3c60f24.setIcon(icon_782c8755e3543325c4d1e095baf7e04e);
#
#
#             var marker_ee6f608fd48835dc254d337754e45e6a = L.marker(
#                 [41.966496, -87.76147],
#                 {
# }
#             ).addTo(map_f7638503ce0461460885430e5c4acdb8);
#
#
#             var icon_bb85508871daf1ac6aa5b0b3fa392e7a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0df5c5b53583ca758e0f533d14b7c813 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1dab9f1ab5fb38f606dd1e8b92c2f89 = $(`&lt;div id=&quot;html_f1dab9f1ab5fb38f606dd1e8b92c2f89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;End&lt;/div&gt;`)[0];
#                 popup_0df5c5b53583ca758e0f533d14b7c813.setContent(html_f1dab9f1ab5fb38f606dd1e8b92c2f89);
#
#
#
#         marker_ee6f608fd48835dc254d337754e45e6a.bindPopup(popup_0df5c5b53583ca758e0f533d14b7c813)
#         ;
#
#
#
#
#                 marker_ee6f608fd48835dc254d337754e45e6a.setIcon(icon_bb85508871daf1ac6aa5b0b3fa392e7a);
#
#
#             var poly_line_4b7f707c15542ae803908e6580cf4eb0 = L.polyline(
#                 [[41.966442, -87.76127], [41.966496, -87.76147]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_f7638503ce0461460885430e5c4acdb8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a87bfe60214fa04d50e76b014e537c99 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a87bfe60214fa04d50e76b014e537c99&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a87bfe60214fa04d50e76b014e537c99 = L.map(
#                 &quot;map_a87bfe60214fa04d50e76b014e537c99&quot;,
#                 {
#                     center: [41.9663285, -87.760913],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 50,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_25aaca6640a56d0e30c6309018a07cc2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_25aaca6640a56d0e30c6309018a07cc2.addTo(map_a87bfe60214fa04d50e76b014e537c99);
#
#
#             var marker_64adcb67b8e2f7881fa08de2789be150 = L.marker(
#                 [41.96631, -87.76071],
#                 {
# }
#             ).addTo(map_a87bfe60214fa04d50e76b014e537c99);
#
#
#             var icon_f8c69b0e41c3a7e05538a38c76fbabe3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_dcffcc48adaa96471d06aeefc7de92db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c0638c5614e59773977a63a01013cbd = $(`&lt;div id=&quot;html_9c0638c5614e59773977a63a01013cbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_dcffcc48adaa96471d06aeefc7de92db.setContent(html_9c0638c5614e59773977a63a01013cbd);
#
#
#
#         marker_64adcb67b8e2f7881fa08de2789be150.bindPopup(popup_dcffcc48adaa96471d06aeefc7de92db)
#         ;
#
#
#
#
#                 marker_64adcb67b8e2f7881fa08de2789be150.setIcon(icon_f8c69b0e41c3a7e05538a38c76fbabe3);
#
#
#             var marker_b2e4186b6260c0e707c7937601c53068 = L.marker(
#                 [41.966347, -87.761116],
#                 {
# }
#             ).addTo(map_a87bfe60214fa04d50e76b014e537c99);
#
#
#             var icon_d36a9daf03acb9fa88e6d43f9e162ae9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6a7abcf334beacd74920463f4ebc75f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2823c29b4b99b81116e73195f3704be9 = $(`&lt;div id=&quot;html_2823c29b4b99b81116e73195f3704be9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;End&lt;/div&gt;`)[0];
#                 popup_6a7abcf334beacd74920463f4ebc75f8.setContent(html_2823c29b4b99b81116e73195f3704be9);
#
#
#
#         marker_b2e4186b6260c0e707c7937601c53068.bindPopup(popup_6a7abcf334beacd74920463f4ebc75f8)
#         ;
#
#
#
#
#                 marker_b2e4186b6260c0e707c7937601c53068.setIcon(icon_d36a9daf03acb9fa88e6d43f9e162ae9);
#
#
#             var poly_line_e35f46ef258ba36c7e57c1ba8d59d02d = L.polyline(
#                 [[41.96631, -87.76071], [41.966347, -87.761116]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_a87bfe60214fa04d50e76b014e537c99);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44f6218b85db06a4e67014e771f67a9d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44f6218b85db06a4e67014e771f67a9d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44f6218b85db06a4e67014e771f67a9d = L.map(
#                 &quot;map_44f6218b85db06a4e67014e771f67a9d&quot;,
#                 {
#                     center: [41.966605, -87.75986],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 50,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_839f2ad3d72be2c368e5fb81ef23f5c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_839f2ad3d72be2c368e5fb81ef23f5c5.addTo(map_44f6218b85db06a4e67014e771f67a9d);
#
#
#             var marker_090098c8d13b6df658fb7b7bd7647658 = L.marker(
#                 [41.96667, -87.75977],
#                 {
# }
#             ).addTo(map_44f6218b85db06a4e67014e771f67a9d);
#
#
#             var icon_09461dd129aaaba0a7a9d7dd77e1d9f5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4f3180ed5a2df1998ff35384db78f748 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eda386837e5a91f9a4bd1d2b95c337c6 = $(`&lt;div id=&quot;html_eda386837e5a91f9a4bd1d2b95c337c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_4f3180ed5a2df1998ff35384db78f748.setContent(html_eda386837e5a91f9a4bd1d2b95c337c6);
#
#
#
#         marker_090098c8d13b6df658fb7b7bd7647658.bindPopup(popup_4f3180ed5a2df1998ff35384db78f748)
#         ;
#
#
#
#
#                 marker_090098c8d13b6df658fb7b7bd7647658.setIcon(icon_09461dd129aaaba0a7a9d7dd77e1d9f5);
#
#
#             var marker_4570888532c780e10c43bf06258dd9bf = L.marker(
#                 [41.96654, -87.75995],
#                 {
# }
#             ).addTo(map_44f6218b85db06a4e67014e771f67a9d);
#
#
#             var icon_c1b7403d5c532a36a49074055cf475f3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_229e98d1023d1884df0d7a36371d4951 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72c4e3b2da9f2fa95f207f65e1f97e4a = $(`&lt;div id=&quot;html_72c4e3b2da9f2fa95f207f65e1f97e4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;End&lt;/div&gt;`)[0];
#                 popup_229e98d1023d1884df0d7a36371d4951.setContent(html_72c4e3b2da9f2fa95f207f65e1f97e4a);
#
#
#
#         marker_4570888532c780e10c43bf06258dd9bf.bindPopup(popup_229e98d1023d1884df0d7a36371d4951)
#         ;
#
#
#
#
#                 marker_4570888532c780e10c43bf06258dd9bf.setIcon(icon_c1b7403d5c532a36a49074055cf475f3);
#
#
#             var poly_line_ea8ffb215a7749d1b4cc7577bb5980b0 = L.polyline(
#                 [[41.96667, -87.75977], [41.96654, -87.75995]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_44f6218b85db06a4e67014e771f67a9d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2c9311b345427bf7bc6ba51082c03cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2c9311b345427bf7bc6ba51082c03cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2c9311b345427bf7bc6ba51082c03cd = L.map(
#                 &quot;map_f2c9311b345427bf7bc6ba51082c03cd&quot;,
#                 {
#                     center: [41.9684355, -87.761185],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 50,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d492228523aa530b59871045243f5360 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d492228523aa530b59871045243f5360.addTo(map_f2c9311b345427bf7bc6ba51082c03cd);
#
#
#             var marker_96fc1e270f9387b7c838d1c4d03f9625 = L.marker(
#                 [41.968548, -87.76115],
#                 {
# }
#             ).addTo(map_f2c9311b345427bf7bc6ba51082c03cd);
#
#
#             var icon_d8f89d454c34f42c95b89435411ef012 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6727110bb490c0ded376493107953ff1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ef95144ae02e17e6810d09d647116de = $(`&lt;div id=&quot;html_7ef95144ae02e17e6810d09d647116de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_6727110bb490c0ded376493107953ff1.setContent(html_7ef95144ae02e17e6810d09d647116de);
#
#
#
#         marker_96fc1e270f9387b7c838d1c4d03f9625.bindPopup(popup_6727110bb490c0ded376493107953ff1)
#         ;
#
#
#
#
#                 marker_96fc1e270f9387b7c838d1c4d03f9625.setIcon(icon_d8f89d454c34f42c95b89435411ef012);
#
#
#             var marker_deb0aad205be10f27b5b2b84cb2d4b4d = L.marker(
#                 [41.968323, -87.76122],
#                 {
# }
#             ).addTo(map_f2c9311b345427bf7bc6ba51082c03cd);
#
#
#             var icon_54fb765c1183eca7cc71167de66d89c1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d2fde3fee7aff02d39d2131b5f47f3a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecd7047b079f1e60977861304d7260fe = $(`&lt;div id=&quot;html_ecd7047b079f1e60977861304d7260fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;End&lt;/div&gt;`)[0];
#                 popup_d2fde3fee7aff02d39d2131b5f47f3a3.setContent(html_ecd7047b079f1e60977861304d7260fe);
#
#
#
#         marker_deb0aad205be10f27b5b2b84cb2d4b4d.bindPopup(popup_d2fde3fee7aff02d39d2131b5f47f3a3)
#         ;
#
#
#
#
#                 marker_deb0aad205be10f27b5b2b84cb2d4b4d.setIcon(icon_54fb765c1183eca7cc71167de66d89c1);
#
#
#             var poly_line_7735f84a4ba82a85f3e56a162b33729a = L.polyline(
#                 [[41.968548, -87.76115], [41.968323, -87.76122]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_f2c9311b345427bf7bc6ba51082c03cd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3c378ea822ce4a9435fc78214f08e55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3c378ea822ce4a9435fc78214f08e55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3c378ea822ce4a9435fc78214f08e55 = L.map(
#                 &quot;map_d3c378ea822ce4a9435fc78214f08e55&quot;,
#                 {
#                     center: [41.969770499999996, -87.7577225],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 50,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa0859e7bfb0e9076da52cb66ff457a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fa0859e7bfb0e9076da52cb66ff457a8.addTo(map_d3c378ea822ce4a9435fc78214f08e55);
#
#
#             var marker_788a333302e6974942b2d599a5f4d587 = L.marker(
#                 [41.969788, -87.75761],
#                 {
# }
#             ).addTo(map_d3c378ea822ce4a9435fc78214f08e55);
#
#
#             var icon_4870880631aeaaebea2ec79f42f48d72 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_396f9367243ebfd63e14fe6a606b9987 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e84ee76358f8ac397e434efe4906481 = $(`&lt;div id=&quot;html_3e84ee76358f8ac397e434efe4906481&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_396f9367243ebfd63e14fe6a606b9987.setContent(html_3e84ee76358f8ac397e434efe4906481);
#
#
#
#         marker_788a333302e6974942b2d599a5f4d587.bindPopup(popup_396f9367243ebfd63e14fe6a606b9987)
#         ;
#
#
#
#
#                 marker_788a333302e6974942b2d599a5f4d587.setIcon(icon_4870880631aeaaebea2ec79f42f48d72);
#
#
#             var marker_fb008aa34ca63a1d898cd8b91d38762b = L.marker(
#                 [41.969753, -87.757835],
#                 {
# }
#             ).addTo(map_d3c378ea822ce4a9435fc78214f08e55);
#
#
#             var icon_1dd8a42c95fd87f7be65f97386de24fc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_62fa1b828afa57cce635ba3bc0fe2639 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb6f3d56ed894261ed8d94b9a6247d65 = $(`&lt;div id=&quot;html_bb6f3d56ed894261ed8d94b9a6247d65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;End&lt;/div&gt;`)[0];
#                 popup_62fa1b828afa57cce635ba3bc0fe2639.setContent(html_bb6f3d56ed894261ed8d94b9a6247d65);
#
#
#
#         marker_fb008aa34ca63a1d898cd8b91d38762b.bindPopup(popup_62fa1b828afa57cce635ba3bc0fe2639)
#         ;
#
#
#
#
#                 marker_fb008aa34ca63a1d898cd8b91d38762b.setIcon(icon_1dd8a42c95fd87f7be65f97386de24fc);
#
#
#             var poly_line_117d38df8c3c9c4477faab49d54652ee = L.polyline(
#                 [[41.969788, -87.75761], [41.969753, -87.757835]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_d3c378ea822ce4a9435fc78214f08e55);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_923e93744a518cf296620d43caf858ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
# ...
#                 [[32.894093, -96.47946], [32.89402, -96.47928]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_527babd5b47ff7b82926efdaee555127);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26c6ced1fbbab5390422febc3e07e469 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26c6ced1fbbab5390422febc3e07e469&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26c6ced1fbbab5390422febc3e07e469 = L.map(
#                 &quot;map_26c6ced1fbbab5390422febc3e07e469&quot;,
#                 {
#                     center: [32.850189, -96.569435],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 50,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a434f4fac8960df91353d90341e3fac0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a434f4fac8960df91353d90341e3fac0.addTo(map_26c6ced1fbbab5390422febc3e07e469);
#
#
#             var marker_f5fb920cecb0b8c2af6a72dcfe8ef073 = L.marker(
#                 [32.850098, -96.56954],
#                 {
# }
#             ).addTo(map_26c6ced1fbbab5390422febc3e07e469);
#
#
#             var icon_d88118310f21589055f1daa19b3e5c1f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8865cc37701d1a5b97e77127ea18baf5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa32d61239acced66bcb5d8f13b523c0 = $(`&lt;div id=&quot;html_aa32d61239acced66bcb5d8f13b523c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_8865cc37701d1a5b97e77127ea18baf5.setContent(html_aa32d61239acced66bcb5d8f13b523c0);
#
#
#
#         marker_f5fb920cecb0b8c2af6a72dcfe8ef073.bindPopup(popup_8865cc37701d1a5b97e77127ea18baf5)
#         ;
#
#
#
#
#                 marker_f5fb920cecb0b8c2af6a72dcfe8ef073.setIcon(icon_d88118310f21589055f1daa19b3e5c1f);
#
#
#             var marker_16f52735f7df6c92769d39d3817602c0 = L.marker(
#                 [32.85028, -96.56933],
#                 {
# }
#             ).addTo(map_26c6ced1fbbab5390422febc3e07e469);
#
#
#             var icon_2447827cb35ba6b2baba274ea7dc8551 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e7521a700daa1af2af6ff9ae3d8adbcd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02c559e60f098280a92b92e3468c07fe = $(`&lt;div id=&quot;html_02c559e60f098280a92b92e3468c07fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;End&lt;/div&gt;`)[0];
#                 popup_e7521a700daa1af2af6ff9ae3d8adbcd.setContent(html_02c559e60f098280a92b92e3468c07fe);
#
#
#
#         marker_16f52735f7df6c92769d39d3817602c0.bindPopup(popup_e7521a700daa1af2af6ff9ae3d8adbcd)
#         ;
#
#
#
#
#                 marker_16f52735f7df6c92769d39d3817602c0.setIcon(icon_2447827cb35ba6b2baba274ea7dc8551);
#
#
#             var poly_line_cf6480ed65f2bc13f4a999e26abbb051 = L.polyline(
#                 [[32.850098, -96.56954], [32.85028, -96.56933]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_26c6ced1fbbab5390422febc3e07e469);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26cb82c46558a524850a22c4f1e04428 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26cb82c46558a524850a22c4f1e04428&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26cb82c46558a524850a22c4f1e04428 = L.map(
#                 &quot;map_26cb82c46558a524850a22c4f1e04428&quot;,
#                 {
#                     center: [32.841814, -96.56956],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 50,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a4c136f937f9d7685b96d64398e9bc5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4a4c136f937f9d7685b96d64398e9bc5.addTo(map_26cb82c46558a524850a22c4f1e04428);
#
#
#             var marker_636b848ec77feb14f06cb319028fb707 = L.marker(
#                 [32.841743, -96.56952],
#                 {
# }
#             ).addTo(map_26cb82c46558a524850a22c4f1e04428);
#
#
#             var icon_c9432683d28cf15919c5401df4a70c86 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_943bc15c3e62fc35a2e2ddbaf2af777e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b5490b2476222752f7aff4a37aa60ac = $(`&lt;div id=&quot;html_8b5490b2476222752f7aff4a37aa60ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_943bc15c3e62fc35a2e2ddbaf2af777e.setContent(html_8b5490b2476222752f7aff4a37aa60ac);
#
#
#
#         marker_636b848ec77feb14f06cb319028fb707.bindPopup(popup_943bc15c3e62fc35a2e2ddbaf2af777e)
#         ;
#
#
#
#
#                 marker_636b848ec77feb14f06cb319028fb707.setIcon(icon_c9432683d28cf15919c5401df4a70c86);
#
#
#             var marker_44ce7f616615ef0e7604c20eb70feea4 = L.marker(
#                 [32.841885, -96.5696],
#                 {
# }
#             ).addTo(map_26cb82c46558a524850a22c4f1e04428);
#
#
#             var icon_81d03abb2a54bbcfe6f709f58ec89d2a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_314e1b6663af5dec68b5739d50343d3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13e27eb3d46c67ff0278dcad897743ac = $(`&lt;div id=&quot;html_13e27eb3d46c67ff0278dcad897743ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;End&lt;/div&gt;`)[0];
#                 popup_314e1b6663af5dec68b5739d50343d3c.setContent(html_13e27eb3d46c67ff0278dcad897743ac);
#
#
#
#         marker_44ce7f616615ef0e7604c20eb70feea4.bindPopup(popup_314e1b6663af5dec68b5739d50343d3c)
#         ;
#
#
#
#
#                 marker_44ce7f616615ef0e7604c20eb70feea4.setIcon(icon_81d03abb2a54bbcfe6f709f58ec89d2a);
#
#
#             var poly_line_10b7edc19d02f4821b66e6e0a486d1b1 = L.polyline(
#                 [[32.841743, -96.56952], [32.841885, -96.5696]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_26cb82c46558a524850a22c4f1e04428);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Removing nonsensical observations

# %% [markdown]
# Now, we've obtained iOS and Android datasets that do not contain any null values. However, the measured data may have technical issues in it that need to be covered. For example, eventEnd - eventStart must be equal to eventDurationSpeed, within tolerance.
#
# Completing the following sanity checks will ensure that our data is clean and logical to be used for our classification model.
# - eventEnd - eventStart = eventDurationSeconds
# - eventMilesDriven > 0

# %%
ios_data['eventDurationSeconds'] = ios_data['eventEnd'] - ios_data['eventStart']
android_data['eventDurationSeconds'] = android_data['eventEnd'] - android_data['eventStart']

ios_data = ios_data[ios_data['eventMilesDriven'] > 0]
android_data = android_data[android_data['eventMilesDriven'] > 0]

# %% [markdown]
# ## Preprocessing pipeline

# %% [markdown]
# To preprocess our data for our model, we first remove internal features. We apply winsorization on our outliers for each feature. We one-hot encode the eventSensorDetectionMthd feature and select the relevant features for each observation depending on eventSensorDetectionMthd. We augment new features that we believe will be valuable to our model, and finally, we standardize our numerical features.

# %% [markdown]
# ### Remove internal features

# %%
def remove_internal_features(df):
    df.drop(columns=['payloadCreation', 'eventAction', 'validity_mean'], inplace=True)

remove_internal_features(ios_data)
remove_internal_features(android_data)

# %% [markdown]
# ### Apply winsorization on outliers

# %%
import scipy.stats as stats

def winsorize_outliers(df):
  outlier_cols = df.drop(columns=['init_time', 'eventStart', 'eventEnd', 'eventType', 'eventDurationSeconds', 'eventSensorDetectionMthd', 'eventSpeedChange']).columns.tolist()
  for outlier_col in outlier_cols:
    df[outlier_col] = stats.mstats.winsorize(df[outlier_col], limits=[0.01, 0.01])

winsorize_outliers(ios_data)
winsorize_outliers(android_data)

# %% [markdown]
# ### Selecting relevant features from eventSensorDetectionMthd
# eventSensorDetectionMthd (gyroscope alignment):
# 0 = none, gyroscope not aligned, use gps for calculations
# 1 = vertical, gyroscope aligned with gravity only
# 2 = full, gyroscope fully aligned, most accurate

# %%
def get_relevant_features(df):
    # Print unique values and counts
    print("unique values:", df['eventSensorDetectionMthd'].unique())
    print("unique counts:", df['eventSensorDetectionMthd'].value_counts())

    df['eventSensorDetectionMthd'] = df['eventSensorDetectionMthd'].astype(int)

    # One-hot encode eventSensorDetectionMthd
    df_encoded = pd.get_dummies(df, columns=['eventSensorDetectionMthd'], prefix='eventSensorDetectionMthd', dtype=int)

    # Make sure all one-hot columns exist
    for col in ['eventSensorDetectionMthd_0', 'eventSensorDetectionMthd_1', 'eventSensorDetectionMthd_2']:
        if col not in df_encoded.columns:
            df_encoded[col] = 0

    # Initialize the new columns with NaN
    df_encoded['radius'] = np.nan
    df_encoded['angleChange'] = np.nan
    df_encoded['angularChangePerSecond'] = np.nan
    df_encoded['medianAcc'] = np.nan
    df_encoded['p75Acc'] = np.nan
    df_encoded['p95Acc'] = np.nan

    # Alignment State 0 (use GPS)
    if 'eventSensorDetectionMthd_0' in df_encoded.columns:
        mask0 = df_encoded['eventSensorDetectionMthd_0'] == 1
        if 'gps_radius' in df_encoded.columns:
            df_encoded.loc[mask0, 'radius'] = df_encoded.loc[mask0, 'gps_radius']
        if 'bearingAngleChange' in df_encoded.columns:
            df_encoded.loc[mask0, 'angleChange'] = df_encoded.loc[mask0, 'bearingAngleChange']
        if 'bearing_angular_change_per_second' in df_encoded.columns:
            df_encoded.loc[mask0, 'angularChangePerSecond'] = df_encoded.loc[mask0, 'bearing_angular_change_per_second']
        if 'gpsMedianLateralAccel' in df_encoded.columns:
            df_encoded.loc[mask0, 'medianAcc'] = df_encoded.loc[mask0, 'gpsMedianLateralAccel']
        if 'gpsP75LateralAccel' in df_encoded.columns:
            df_encoded.loc[mask0, 'p75Acc'] = df_encoded.loc[mask0, 'gpsP75LateralAccel']
        if 'gpsP95LateralAccel' in df_encoded.columns:
            df_encoded.loc[mask0, 'p95Acc'] = df_encoded.loc[mask0, 'gpsP95LateralAccel']

    # Alignment State 1 (vertically aligned)
    if 'eventSensorDetectionMthd_1' in df_encoded.columns:
        mask1 = df_encoded['eventSensorDetectionMthd_1'] == 1
        if 'mems_radius' in df_encoded.columns:
            df_encoded.loc[mask1, 'radius'] = df_encoded.loc[mask1, 'mems_radius']
        if 'gyroAngleChange' in df_encoded.columns:
            df_encoded.loc[mask1, 'angleChange'] = df_encoded.loc[mask1, 'gyroAngleChange']
        if 'gyro_angular_change_per_second' in df_encoded.columns:
            df_encoded.loc[mask1, 'angularChangePerSecond'] = df_encoded.loc[mask1, 'gyro_angular_change_per_second']
        if 'memsMedianHorizontalNorm' in df_encoded.columns:
            df_encoded.loc[mask1, 'medianAcc'] = df_encoded.loc[mask1, 'memsMedianHorizontalNorm']
        if 'memsP75HorizontalNorm' in df_encoded.columns:
            df_encoded.loc[mask1, 'p75Acc'] = df_encoded.loc[mask1, 'memsP75HorizontalNorm']
        if 'memsP95HorizontalNorm' in df_encoded.columns:
            df_encoded.loc[mask1, 'p95Acc'] = df_encoded.loc[mask1, 'memsP95HorizontalNorm']

    # Alignment State 2 (fully aligned)
    if 'eventSensorDetectionMthd_2' in df_encoded.columns:
        mask2 = df_encoded['eventSensorDetectionMthd_2'] == 1
        if 'mems_radius' in df_encoded.columns:
            df_encoded.loc[mask2, 'radius'] = df_encoded.loc[mask2, 'mems_radius']
        if 'gyroAngleChange' in df_encoded.columns:
            df_encoded.loc[mask2, 'angleChange'] = df_encoded.loc[mask2, 'gyroAngleChange']
        if 'gyro_angular_change_per_second' in df_encoded.columns:
            df_encoded.loc[mask2, 'angularChangePerSecond'] = df_encoded.loc[mask2, 'gyro_angular_change_per_second']
        if 'memsMedianLateralAccel' in df_encoded.columns:
            df_encoded.loc[mask2, 'medianAcc'] = df_encoded.loc[mask2, 'memsMedianLateralAccel']
        if 'memsP75LateralAccel' in df_encoded.columns:
            df_encoded.loc[mask2, 'p75Acc'] = df_encoded.loc[mask2, 'memsP75LateralAccel']
        if 'memsP95LateralAccel' in df_encoded.columns:
            df_encoded.loc[mask2, 'p95Acc'] = df_encoded.loc[mask2, 'memsP95LateralAccel']

    # Drop original raw columns
    drop_cols = [
        'gps_radius', 'bearingAngleChange', 'bearing_angular_change_per_second',
        'gpsMedianLateralAccel', 'gpsP75LateralAccel', 'gpsP95LateralAccel',
        'mems_radius', 'gyroAngleChange', 'gyro_angular_change_per_second',
        'memsMedianHorizontalNorm', 'memsP75HorizontalNorm', 'memsP95HorizontalNorm',
        'memsMedianLateralAccel', 'memsP75LateralAccel', 'memsP95LateralAccel'
    ]
    df_encoded = df_encoded.drop(columns=[col for col in drop_cols if col in df_encoded.columns])

    return df_encoded

# Apply to datasets
ios_data = get_relevant_features(ios_data)
android_data = get_relevant_features(android_data)

# %%
ios_data.head()

# %%
ios_data.describe()

# %%
android_data.describe()

# %% [markdown]
# ### Feature augmentation

# %%
def haversine(lat1, lon1, lat2, lon2):
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    r = 3956
    return c * r

# %%
def augment_features(df):
    df_augmented = df.copy()
    df_augmented['changeLatitude'] = df_augmented["eventEndLatitude"] - df_augmented["eventStartLatitude"]
    df_augmented['changeLongitude'] = df_augmented["eventEndLongitude"] - df_augmented["eventStartLongitude"]
    df_augmented['eventSpeedChange'] = df_augmented['eventEndSpeed'] - df_augmented['eventStartSpeed']
    haversine_dist = haversine(df_augmented['eventStartLatitude'], df_augmented['eventStartLongitude'],
                               df_augmented['eventEndLatitude'], df_augmented['eventEndLongitude'])
    df_augmented['straightness'] = np.divide(haversine_dist, df_augmented['eventMilesDriven'],
                                           out=np.zeros_like(haversine_dist), where=df_augmented['eventMilesDriven']!=0)
    df_augmented['normalizedRadius'] = np.divide(df_augmented['radius'], df_augmented['eventMilesDriven'],
                                                     out=np.zeros_like(df_augmented['radius']), where=df_augmented['eventMilesDriven']!=0)
    df_augmented['averageAcceleration'] = np.divide(df_augmented['eventSpeedChange'], df_augmented['eventDurationSeconds'],
                                              out=np.zeros_like(df_augmented['eventSpeedChange']), where=df_augmented['eventDurationSeconds']!=0)
    df_augmented['accRange'] = df_augmented['p95Acc'] - df_augmented['medianAcc']
    df_augmented['speedRatio'] = np.divide(df_augmented['eventEndSpeed'], df_augmented['eventStartSpeed'],
                                         out=np.zeros_like(df_augmented['eventEndSpeed']), where=df_augmented['eventStartSpeed']!=0)
    df_augmented['angularDisplacementPerMile'] = np.divide(df_augmented['angleChange'], df_augmented['eventMilesDriven'],
                                                                     out=np.zeros_like(df_augmented['angleChange']), where=df_augmented['eventMilesDriven']!=0)
    df_augmented['turnIntensity'] = np.divide(df_augmented['angularChangePerSecond'], df_augmented['eventSampleSpeed'],
                                                      out=np.zeros_like(df_augmented['angularChangePerSecond']), where=df_augmented['eventSampleSpeed']!=0)
    df_augmented['normalizedTurnIntensity'] = np.divide(df_augmented['turnIntensity'], df_augmented['radius'],
                                                                 out=np.zeros_like(df_augmented['turnIntensity']), where=df_augmented['radius']!=0)

    event_timestamp_seconds = df_augmented['init_time'] + df_augmented['eventStart'] / 1000
    event_datetime = pd.to_datetime(event_timestamp_seconds, unit='ms')
    df_augmented['hour'] = event_datetime.dt.hour
    df_augmented['day'] = event_datetime.dt.dayofweek
    df_augmented['month'] = event_datetime.dt.month
    is_weekday = df_augmented['day'] < 5
    is_morning_rush = (df_augmented['hour'] >= 7) & (df_augmented['hour'] < 10)
    is_evening_rush = (df_augmented['hour'] >= 16) & (df_augmented['hour'] < 19)
    df_augmented['is_rush_hour'] = (is_weekday & (is_morning_rush | is_evening_rush)).astype(int)
    return df_augmented

# %%
ios_data = augment_features(ios_data)
android_data = augment_features(android_data)

# %%
ios_data.head()

# %% [markdown]
# ### Feature fusion

# %%
# not working, will add these features later

# %% [markdown]
# ### One Hot Encoding

# %%
def one_hot_encode(df, cols):
    for col in cols:
        dummies = pd.get_dummies(df[col], prefix=col, dtype=int)
        df = pd.concat([df, dummies], axis=1)
        df.drop(columns=[col], inplace=True)
    return df

categorical_cols = [] # eventSensorDetectionMthd already encoded
ios_data = one_hot_encode(ios_data, categorical_cols)
android_data = one_hot_encode(android_data, categorical_cols)
categorical_cols += ["eventSensorDetectionMthd"]

# %%
ios_encoded_cols = [col for col in ios_data.columns if any(prefix in col for prefix in categorical_cols)]
android_encoded_cols = [col for col in android_data.columns if any(prefix in col for prefix in categorical_cols)]
print(ios_data[ios_encoded_cols].head())
print(android_data[android_encoded_cols].head())

# %% [markdown]
# ## Standardize

# %% [markdown]
# ### First I'll take out one hot encoded features and time identifiers

# %%
# ios_onehot_cols = []
# for col in ios_data.columns:
#     unique_vals = ios_data[col].dropna().unique()
#     if len(unique_vals) == 2 and set(unique_vals).issubset({0, 1, 0.0, 1.0}):
#         ios_onehot_cols.append(col)

# %% [markdown]
# ### Create column that standardizes column values that are not onehot encoded or define time

# %%
# ios_numerical_cols = ios_data.select_dtypes(include=[np.number]).columns.tolist()
# time_cols = ['init_time', 'eventStart', 'eventEnd']
# ios_cols_to_standardize = [col for col in ios_numerical_cols if col not in ios_onehot_cols and col not in time_cols]
# ios_cols_to_standardize

# %%
# print("total columns: {}".format(len(ios_data.columns)))
# print("one-hot columns (skipping): {}".format(len(ios_onehot_cols)))
# print("iOS standardizing: {}".format(len(ios_cols_to_standardize)))

# %% [markdown]
# ### This will use standardized scaler

# %%
# # Replace inf values with NaN
# ios_data[ios_cols_to_standardize] = ios_data[ios_cols_to_standardize].replace([np.inf, -np.inf], np.nan)
# # Replace NaN values with columns mean
# ios_data[ios_cols_to_standardize] = ios_data[ios_cols_to_standardize].fillna(
#     ios_data[ios_cols_to_standardize].mean()
# )

# ios_scaler = StandardScaler()
# ios_data[ios_cols_to_standardize] = ios_scaler.fit_transform(ios_data[ios_cols_to_standardize])

# print("Complete!")

# %% [markdown]
# # Repeat for Android

# %%
# android_onehot_cols = []
# for col in android_data.columns:
#     unique_vals = android_data[col].dropna().unique()
#     if len(unique_vals) == 2 and set(unique_vals).issubset({0, 1, 0.0, 1.0}):
#         android_onehot_cols.append(col)
# android_numerical_cols = android_data.select_dtypes(include=[np.number]).columns.tolist()
# android_cols_to_standardize = [col for col in android_numerical_cols if col not in android_onehot_cols and col not in time_cols]

# print("total columns: {}".format(len(android_data.columns)))
# print("one-hot columns (skipping): {}".format(len(android_onehot_cols)))
# print("android standardizing: {}".format(len(android_cols_to_standardize)))

# android_data[android_cols_to_standardize] = android_data[android_cols_to_standardize].replace([np.inf, -np.inf], np.nan)
# android_data[android_cols_to_standardize] = android_data[android_cols_to_standardize].fillna(
#     android_data[android_cols_to_standardize].mean()
# )

# android_scaler = StandardScaler()
# android_data[android_cols_to_standardize] = android_scaler.fit_transform(android_data[android_cols_to_standardize])

# print("Complete!")

# %% [markdown]
# ### Full pipeline

# %%
from sklearn.preprocessing import StandardScaler

def standardize_features(df):
    df_processed = df.copy()
    time_cols = ['init_time', 'eventStart', 'eventEnd', 'eventType']
    onehot_cols = []
    for col in df_processed.columns:
        unique_vals = df_processed[col].dropna().unique()
        if len(unique_vals) <= 2 and set(unique_vals).issubset({0, 1, 0.0, 1.0}):
            onehot_cols.append(col)

    print(onehot_cols)
    cols_to_exclude = time_cols + onehot_cols
    numerical_cols = df_processed.select_dtypes(include=np.number).columns.tolist()
    print(numerical_cols)
    cols_to_standardize = [col for col in numerical_cols if col not in cols_to_exclude]
    print(cols_to_standardize)

    scaler = StandardScaler()
    df_processed[cols_to_standardize] = scaler.fit_transform(df_processed[cols_to_standardize])
    return df_processed

# %%
ios_data = standardize_features(ios_data)
android_data = standardize_features(android_data)

# %%
ios_data.head()

# %%
android_data.head()

# %%
X_ios = ios_data.iloc[:, 4:]
X_ios.head()

# %%
X_android = android_data.iloc[:, 4:]
X_android.head()

# %%
left_ios_data = ios_data[ios_data['eventType'] == 4].copy()
X_ios_left = left_ios_data.iloc[:, 4:]
right_ios_data = ios_data[ios_data['eventType'] == 5].copy()
X_ios_right = right_ios_data.iloc[:, 4:]

left_android_data = android_data[android_data['eventType'] == 4].copy()
X_android_left = left_android_data.iloc[:, 4:]
right_android_data = android_data[android_data['eventType'] == 5].copy()
X_android_right = right_android_data.iloc[:, 4:]

combined_data = pd.concat([ios_data, android_data], ignore_index=True)
X_combined = combined_data.iloc[:, 4:]
left_combined_data = combined_data[combined_data['eventType'] == 4].copy()
X_combined_left = left_combined_data.iloc[:, 4:]
right_combined_data = combined_data[combined_data['eventType'] == 5].copy()
X_combined_right = right_combined_data.iloc[:, 4:]

# %% [markdown]
# # Clustering
# Now, we will be clustering for different types of turns, including left turns, right turns, for ios and android, as well as both combined for left and right.

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.decomposition import PCA
import hdbscan

def cluster_grid_search(estimator_class, param_grid, X, scoring = 1, random_state=42):
    if hasattr(X, "values"):
        X_arr = X.values
    else:
        X_arr = np.asarray(X)

    keys, values = zip(*param_grid.items())
    param_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]

    best_score = -1
    best_model, best_params, best_labels = None, None, None

    for params in param_combinations:
        if "random_state" in estimator_class().get_params().keys():
            params["random_state"] = random_state

        try:
            model = estimator_class(**params)
            model.fit(X_arr)

            if hasattr(model, "labels_"):  # HDBSCAN-like
                labels = model.labels_
            else:  # GMM-like
                labels = model.predict(X_arr)

            unique_labels = set(labels)
            if len(unique_labels - {-1}) < 2:
                continue
            mask = labels != -1 if -1 in labels else np.ones(len(labels), dtype=bool)
            if np.sum(mask) < 2:
                continue

            if scoring == 1:
              score = calinski_harabasz_score(X_arr[mask], labels[mask])
            elif scoring == 2:
              score = davies_bouldin_score(X_arr[mask], labels[mask])
            else:
              score = silhouette_score(X_arr[mask], labels[mask])

            if score > best_score:
                best_score = score
                best_model = model
                best_params = params
                best_labels = labels
        except Exception as e:
            print(f"Failed for params {params}: {e}")
            continue

    if best_labels is not None:
        n_features = X_arr.shape[1]

        if n_features == 2:
            plt.figure(figsize=(6, 5))
            plt.scatter(X_arr[:, 0], X_arr[:, 1], c=best_labels, cmap="tab10", s=30, alpha=0.7)
            plt.title(f"Best Clustering\n{best_params}\nCH={best_score:.3f}")
            plt.show()

        elif n_features == 3:
            fig = plt.figure(figsize=(7, 6))
            ax = fig.add_subplot(111, projection="3d")
            ax.scatter(X_arr[:, 0], X_arr[:, 1], X_arr[:, 2], c=best_labels, cmap="tab10", s=30, alpha=0.7)
            ax.set_title(f"Best Clustering\n{best_params}\nCH={best_score:.3f}")
            plt.show()

        else:
            pca = PCA(n_components=3)
            X_pca = pca.fit_transform(X_arr)
            fig = plt.figure(figsize=(7, 6))
            ax = fig.add_subplot(111, projection="3d")
            ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=best_labels, cmap="tab10", s=30, alpha=0.7)
            ax.set_title(f"Best Clustering (PCA 3D)\n{best_params}\nCH={best_score:.3f}")
            plt.show()

    return best_model, best_params, best_labels, best_score

# %%
from sklearn.decomposition import PCA
import hdbscan

param_grid = {
    "min_cluster_size": [5, 10, 20, 50],
    "min_samples": [None, 5, 10]
}

datasets = {
    "Left Android": X_android_left,
    "Right Android": X_android_right,
    "Android": X_android,
    "Left iOS": X_ios_left,
    "Right iOS": X_ios_right,
    "iOS": X_ios,
    "Left Combined": X_combined_left,
    "Right Combined": X_combined_right,
    "Combined": X_combined
}

results = {}

for name, data in datasets.items():
    print(f"--- Running Analysis for: {name} ---")

    if not data.empty:
        X_pca = PCA(n_components=8).fit_transform(data)

        best_model, best_params, best_labels, best_score = cluster_grid_search(
            hdbscan.HDBSCAN,
            param_grid,
            scoring = 1
            X_pca
        )

        results[name] = {
            'best_params': best_params,
            'best_score': best_score,
            'scoring': 1
        }

        print(f"Best HDBSCAN Params for {name}: {best_params}")
        print(f"Best CH Score for {name}: {best_score}\n")

        best_model, best_params, best_labels, best_score = cluster_grid_search(
            hdbscan.HDBSCAN,
            param_grid,
            scoring = 2
            X_pca
        )

        results[name] = {
            'best_params': best_params,
            'best_score': best_score,
            'scoring': 2
        }

        print(f"Best HDBSCAN Params for {name}: {best_params}")
        print(f"Best DB Score for {name}: {best_score}\n")

        best_model, best_params, best_labels, best_score = cluster_grid_search(
            hdbscan.HDBSCAN,
            param_grid,
            scoring = 3
            X_pca
        )

        results[name] = {
            'best_params': best_params,
            'best_score': best_score,
            'scoring': 3
        }

        print(f"Best HDBSCAN Params for {name}: {best_params}")
        print(f"Best Silhouette Score for {name}: {best_score}\n")
    else:
        print(f"Skipping {name} because it is empty.\n")

# %%
from sklearn.cluster import KMeans

param_grid = {
    "n_clusters": [2, 3, 4, 5, 6],
    "init": ["k-means++", "random"],
    "n_init": [10, 20]
}

results_kmeans = {}

for name, data in datasets.items():
    print(f"--- Running KMeans Analysis for: {name} ---")

    if not data.empty:
        X_pca = PCA(n_components=8).fit_transform(data)

        best_model, best_params, best_labels, best_score = cluster_grid_search(
            KMeans,
            param_grid,
            X_pca
        )

        results_kmeans[name] = {
            'best_params': best_params,
            'best_score': best_score
        }

        print(f"Best KMeans Params for {name}: {best_params}")
        print(f"Best CH Score for {name}: {best_score}\n")
    else:
        print(f"Skipping {name} because it is empty.\n")

# %%
from sklearn.mixture import GaussianMixture
import warnings
warnings.filterwarnings("ignore")


param_grid_gmm = {
    "n_components": [2, 3, 5, 8, 10],
    "covariance_type": ["full", "tied", "diag", "spherical"]
}
gmm_result = {}

for name, data in datasets.items():
    print(f"--- Running Analysis for: {name} ---")

    if not data.empty:
        X_pca = PCA(n_components=8).fit_transform(data)


        best_model_gmm, best_params_gmm, best_labels_gmm, best_score_gmm = cluster_grid_search(
            GaussianMixture,
            param_grid_gmm,
            X_pca
        )

        results[name] = {
            'best_params': best_params_gmm,
            'best_score': best_score_gmm
        }

        print(f"Best GMM Params for {name}: {best_params_gmm}")
        print(f"Best GMM CH Score for {name}: {best_score_gmm}\n")
    else:
        print(f"Skipping {name} because it is empty.\n")
